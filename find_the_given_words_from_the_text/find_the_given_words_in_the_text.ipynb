# %%
def check_word(the_word,txt):
  #to run 'find_word' function or not
  set_second_function = False
  
  #Get the sentences with split 
  for sentences in txt.split("."):
    #Checking 
    for word in sentences.split(" "):
      if word.lower() == the_word:
        set_second_function = True
        break
    if set_second_function:
      break

  if set_second_function == True:
    find_word(the_word,txt)
  else:
    print("\nThere are no such words as \"{}\".".format(the_word))

def find_word(the_word,txt):
  #Count => show how many sentences that conatins 'the_word' word.
  count=1

  #iteration => prevent repeated outputs 
  iteration = False
  
  #Get the sentences with split 
  for sentences in txt.split("."):
    #Checking 
    for word in sentences.split(" "):
      if word.lower() == the_word:
        if iteration == True:

          iteration = False
          break
        print("\n{}->{}".format(count,sentences))
        iteration = True
        count+=1 
        break
    iteration = False



#Input and check the word if it is valid or not 
the_word=input("Please enter a word: ").lower().strip()
while not the_word.isalpha():
  the_word=input("Please enter a valid word !\n=> ").lower()
  if the_word.isalpha():
    break

#Open the txt file
inFile=open("the_text.txt","r")
txt_file=inFile.read()
inFile.close()

#Check if there are such words as 'the_word'
check_word(the_word,txt_file)
# Out:
# Please enter a word: eNliGhTeNmEnT
#
# 1->But for Hegel, the Enlightenment had betrayed itself, left unfulﬁlled its religious mission, because of the nature of the image of man which it produced, which emphasises human autonomy and self-sufﬁciency
#
# 2-> These views of the relationship between Enlightenment and religion have been enormously inﬂuential
#
# 3->Nor was Hegel’s view of the religious thought of the Enlightenment without considerable substance, especially in the case of France
#
# 4-> And again, economic thought in the Enlightenment in the works of such men as Adam Smith did deﬁne individuals as autonomous seekers of self-interest rather than of salvation
#
# 5-> However, our picture of the Enlightenment as ‘modern paganism’ starts to become considerably more complex once we abandon this focus on the small group of determinedly anti-religious thinkers who are almost conﬁned to the French Enlightenment
#
# ...

# %% [markdown]
# Please enter a word: 2
#
# Please enter a valid word !
#
# => 3*
#
# Please enter a valid word !
#
# => *
#
# Please enter a valid word !
#
# => -
#
# Please enter a valid word !
#
# => ?
#
# Please enter a valid word !
#
# => EnLİghTenment
#
# Please enter a valid word !
#
# => EnLighTenment
#
# 1->But for Hegel, the Enlightenment had betrayed itself, left unfulﬁlled its religious mission, because of the nature of the image of man which it produced, which emphasises human autonomy and self-sufﬁciency
#
# 2-> These views of the relationship between Enlightenment and religion have been enormously inﬂuential
#
# 3-> Nor was Hegel’s view of the religious thought of the Enlightenment without considerable substance, especially in the case of France
#
# 4-> And again, economic thought in the Enlightenment in the works of such men as Adam Smith did deﬁne individuals as autonomous seekers of self-interest rather than of salvation
#
# 5-> However, our picture of the Enlightenment as ‘modern paganism’ starts to become considerably more complex once we abandon this focus on the small group of determinedly anti-religious thinkers who are almost conﬁned to the French Enlightenment
#
# 6-> As we have already seen, thinkers of the stature of Hegel saw the Enlightenment as a movement which could not be understood except within religious categories, however one assesses his claim that the Enlightenment had betrayed man ’s religious nature
#
# 7-> In fact the Enlightenment produced a wide variety of responses to organised religion, ranging all the way from violent Voltairean hostility to religion, through to attempts to bolster orthodox belief by demonstrating its rationality and accordance with natural law

# %%
s="Enlightenment".lower()
if s.isalnum():
  print("de")
# Out:
# de
